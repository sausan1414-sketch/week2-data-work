# %%
print('ghj')
# Out:
# ghj

# %%
import pandas as pd 
data = [
    {
        "نوع العقار":
          "دور للبيع في شارع شهيد الدين ثم الوطن فهد إبراهيم علي أب, حي النرجس, مدينة الر",
        "السعر": 
        " 1,500,000 ",
        " المميزات":" مشروع ادوار سِـــدرا مشروع يتميز بموقعه الاستراتجي بح"
    },
     {
        "نوع العقار": "دفيلا للبيع في شارع عذبة, حي حطين, مدينة الرياض, م",
        "السعر":" 4,900,000 ",
        " المميزات":" ‏للبيع فلتين مودرن بحي حطين بتصميم مميز والاكثر شر "  
          
  } ,
      {
        "نوع العقار": "فيلا للبيع في شارع خفاف بن ندبة, حي العليا, مدينة ال ",
        "السعر":" 3,800,000",
        " المميزات":"  ‏للبيع فيلا مستخدمة استخدام نظيف مع بيسمنت العمر  "  
          
  } ]
df = pd.DataFrame(data)
df
# Out:
#                                           نوع العقار        السعر  \
# 0  دور للبيع في شارع شهيد الدين ثم الوطن فهد إبرا...   1,500,000
# 1  دفيلا للبيع في شارع عذبة, حي حطين, مدينة الريا...   4,900,000
# 2  فيلا للبيع في شارع خفاف بن ندبة, حي العليا, مد...    3,800,000
#
#                                             المميزات
# 0   مشروع ادوار سِـــدرا مشروع يتميز بموقعه الاست...
# 1   ‏للبيع فلتين مودرن بحي حطين بتصميم مميز والاك...
# 2    ‏للبيع فيلا مستخدمة استخدام نظيف مع بيسمنت ا...

# %%
import httpx
import pandas as pd
response = httpx.get("https://api.thecatapi.com/v1/images/search?limit=10")
data = response.json()          
df = pd.DataFrame(data)

df
# Out:
#            id                                               url  width  height
# 0          sg          https://cdn2.thecatapi.com/images/sg.jpg    640     426
# 1          vq          https://cdn2.thecatapi.com/images/vq.png    640     480
# 2         1b0         https://cdn2.thecatapi.com/images/1b0.gif    500     281
# 3         322         https://cdn2.thecatapi.com/images/322.jpg    600     400
# 4         48r         https://cdn2.thecatapi.com/images/48r.gif    500     281
# 5         bf0         https://cdn2.thecatapi.com/images/bf0.jpg    500     325
# 6         bgd         https://cdn2.thecatapi.com/images/bgd.jpg    500     333
# 7  MTU4NzQwNA  https://cdn2.thecatapi.com/images/MTU4NzQwNA.jpg   1280    1280
# 8   wEg45kYmd   https://cdn2.thecatapi.com/images/wEg45kYmd.jpg   1620    1080
# 9   PEgob-hhL   https://cdn2.thecatapi.com/images/PEgob-hhL.jpg    852    1136

# %%
# !python -m pip install requests
# Out:
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# ...
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# ...
# Using cached urllib3-2.6.2-py3-none-any.whl (131 kB)
# ...
#
#    ---------------------------------------- 0/3 [urllib3]
#    ------------- -------------------------- 1/3 [charset_normalizer]
#    -------------------------- ------------- 2/3 [requests]
#    ---------------------------------------- 3/3 [requests]
#
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /simple/requests/

# %%
pip install beautifulsoup4
# Out:
# ...
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached soupsieve-2.8.1-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached soupsieve-2.8.1-py3-none-any.whl (36 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# ...
#
#    ------------- -------------------------- 1/3 [soupsieve]
#    -------------------------- ------------- 2/3 [beautifulsoup4]
#    ---------------------------------------- 3/3 [beautifulsoup4]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
cookies = {
    'req-device-token': '10db3fb9-c3ab-4f8c-b1af-10e13de5aa5a',
    '_gcl_aw': 'GCL.1766666832.CjwKCAiA3rPKBhBZEiwAhPNFQLcB9PXvBNHWt9Th0ldpL1qYt1Db_WegUkxvXZ4dqjLgFB-4TdzusBoC24YQAvD_BwE',
    '_gcl_gs': '2.1.k1$i1766666828$u117709451',
    '_gcl_au': '1.1.1389985888.1766666832',
ThOfLhYnRD1QMb6SuBSJq4gGoSFZ4u6S1bRhMZoBGiQvqDnwVzuJMo6Kg1Y1wlVqsLEFYhHuZyJd12l3W4Bci3cflymw3fpg1.8; cf_clearance=1rBwPe0rKMeMiNA7EpQtF3sOkMeVmUOY0Vq35SslVog-1766671835-1.2.1.1-Jrq6zV64YH5LAqzieQ5A3sAy9WnQy5sjrsl05UKpvw_SiuIhtfZPEBeavtfYMkCkKketo0gQoUjYB9hl_C2qxSG0BCYNFtuNbBZpIuqK9qviF8l4fsuniETttXyBwCPsFuv7Z1G5lPq6xSuuPi76Lzj6P4C1PptkJFbAwMx6.FmYiPblk9g9nJEYZhmsTIvjMmBsn6nuWmA2sXfpstlT0DrcpGKhsv2PH9ebdWDoHgc; _ga_8DTTM22D6F=GS2.1.s1766671836$o3$g1$t1766672125$j59$l0$h0; _ga=GA1.2.1002122641.1766666832; ttcsid=1766671837651::GztBXP7sJbHzaGdCNtvk.3.1766672126047.0; ttcsid_CFI0VNBC77U110MKDP70=1766671837650::Pvr9U4AAnQP4QgZgVyfa.3.1766672126047.1; _clsk=4hi5ou%5E1766672126160%5E5%5E1%5Ee.clarity.ms%2Fcollect',
}

response = requests.get(
    'https://sa.aqar.fm/%D8%B9%D9%82%D8%A7%D8%B1%D8%A7%D8%AA/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6',
    cookies=cookies,
    headers=headers,
)
html_doc = response.text
assert "You have been blocked" not in html_doc

soup = BeautifulSoup(html_doc)
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# <!-- titles = []
# title_elements = soup.select(title_selector)
# for e in title_elements:
# titles.append(e.get_text())
# titles -->

# %%
title_selector = '#__next > main > div > div._root__Szbd6 > div > div > div._container__Lu67A > div._list__Ka30R > div > a > div > div._content__W4gas > div._titleRow__1AWv1 > h4'
soup.select(title_selector)
# Out:
# [<h4>دور للبيع في شارع شهيد الدين ثم الوطن فهد إبراهيم علي أب, حي النرجس, مدينة الرياض, منطقة الرياض</h4>,
# ...

# %%
pip install docker
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 2.9 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/9.7 MB 7.0 MB/s eta 0:00:02
#    --------------------------- ------------ 6.6/9.7 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 14.2 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
#    ---------------------------------------- 0/2 [pywin32]
# ...

# %%
import httpx
from bs4 import BeautifulSoup
import pandas as pd

def scrape_all_listings():
    """Scrape ALL listings from the page"""
    
    # Fetch the page
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
         "Accept-Language": "ar,en-US;q=0.9,en;q=0.8", 
      }
    
    url = "https://sa.aqar.fm/"
    response = httpx.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find ALL content divs (all listings)
    all_content_divs = soup.select('div.content_W4gas')
    
    print(f"Found {len(all_content_divs)} listing content sections")
    
    # Create list of dictionaries
    list_of_dicts = []
    
    for i, content_div in enumerate(all_content_divs, 1):
        try:
            data = extract_listing_data(content_div)
            data['listing_number'] = i  # Add sequence number
            list_of_dicts.append(data)
            print(f"✓ Added listing #{i}")
        except Exception as e:
            print(f"✗ Error with listing #{i}: {e}")
            continue
    
    return list_of_dicts

# Get all listings
all_listings = scrape_all_listings()

print(f"\n✅ Created list with {len(all_listings)} dictionaries")
# Out:
# Found 0 listing content sections
#
# ✅ Created list with 0 dictionaries
